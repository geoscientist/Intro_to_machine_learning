# %%
import numpy as np
import pandas as pd
from sklearn import decomposition

# %%
data = pd.read_csv('close_prices.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 374 entries, 0 to 373
# Data columns (total 31 columns):
# date    374 non-null object
# AXP     374 non-null float64
# BA      374 non-null float64
# CAT     374 non-null float64
# CSCO    374 non-null float64
# CVX     374 non-null float64
# DD      374 non-null float64
# DIS     374 non-null float64
# GE      374 non-null float64
# GS      374 non-null float64
# HD      374 non-null float64
# IBM     374 non-null float64
# INTC    374 non-null float64
# JNJ     374 non-null float64
# JPM     374 non-null float64
# KO      374 non-null float64
# MCD     374 non-null float64
# MMM     374 non-null float64
# MRK     374 non-null float64
# MSFT    374 non-null float64
# NKE     374 non-null float64
# PFE     374 non-null float64
# PG      374 non-null float64
# T       374 non-null float64
# TRV     374 non-null float64
# UNH     374 non-null float64
# UTX     374 non-null float64
# V       374 non-null float64
# ...

# %%
data.head()
# Out:
#          date        AXP          BA        CAT       CSCO         CVX  \
# 0  2013-09-23  76.440002  117.510002  85.029999  24.270000  125.519997
# 1  2013-09-24  76.070000  119.000000  85.110001  24.139999  124.489998
# 2  2013-09-25  75.989998  118.510002  84.500000  24.430000  124.070000
# 3  2013-09-26  76.320000  119.379997  84.199997  23.770000  123.489998
# 4  2013-09-27  75.889999  118.739998  83.800003  23.330000  122.639999
#
#           DD        DIS         GE          GS    ...            PFE  \
# 0  59.409999  64.750000  24.280001  165.250000    ...      28.799999
# 1  59.319997  64.320000  24.320000  162.970001    ...      28.709999
# 2  59.319997  64.449997  24.230000  162.309998    ...      28.490000
# 3  59.509996  65.239998  24.250000  162.289993    ...      28.520000
# 4  59.009995  65.190002  24.049999  159.850006    ...      28.879999
#
#           PG          T        TRV        UNH         UTX           V  \
# ...

# %%
pca = decomposition.PCA(n_components=10)
pca.fit(data.iloc[:, 1:31])
# Out:
# PCA(copy=True, n_components=10, whiten=False)

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.73897118,  0.11007169,  0.04995088,  0.0287492 ,  0.02215448,
#         0.01931577,  0.00674853,  0.00614091,  0.00320594,  0.00305611])

# %%
pca.components_
# Out:
# array([[  1.61383840e-02,   1.20644923e-01,  -5.16612711e-02,
#           5.04842369e-02,  -1.25859933e-01,   1.14089567e-01,
#           2.33906290e-01,  -6.20513749e-03,   2.51227032e-01,
#           2.88996029e-01,  -2.64998795e-01,   9.31320168e-02,
#           9.13948403e-02,   4.69879340e-02,   2.90549417e-02,
#          -2.61068828e-02,   3.29615584e-01,   7.13897133e-02,
#           7.62295699e-02,   2.11888868e-01,   2.30922941e-02,
#           7.77316954e-02,  -7.20594590e-03,   1.89479745e-01,
#           3.21564017e-01,   5.36834873e-02,   5.79683946e-01,
#           1.09122230e-04,   8.71614334e-02,  -4.29421420e-02],
#        [  2.33025791e-01,  -1.38102207e-01,   5.64736227e-01,
#           2.94213771e-02,   2.97156167e-01,   7.00723638e-02,
#           2.41633004e-01,   2.26028350e-02,   1.05527180e-01,
#          -3.16032026e-02,   3.56926513e-01,   1.51980885e-01,
#           2.76101639e-01,   6.73887479e-02,   5.03438625e-02,
# ...

# %%
dj_data = pd.read_csv('djia_index.csv')
dj_data.head()
# Out:
#          date          ^DJI
# 0  2013-09-23  15401.379883
# 1  2013-09-24  15334.589844
# 2  2013-09-25  15273.259766
# 3  2013-09-26  15328.299805
# 4  2013-09-27  15258.240234

# %%
data_tr = pca.transform(data.iloc[:, 1:31])

# %%
cor = np.corrcoef(data_tr[:, 0], dj_data.ix[:, 1])
cor[0,1]
# Out:
# 0.90965221930502305

# %%
companies = pd.DataFrame(data.columns[1:], pca.components_[0])

# %%
companies
# Out:
#               0
#  0.016138   AXP
#  0.120645    BA
# -0.051661   CAT
#  0.050484  CSCO
# -0.125860   CVX
#  0.114090    DD
#  0.233906   DIS
# -0.006205    GE
#  0.251227    GS
#  0.288996    HD
# -0.264999   IBM
#  0.093132  INTC
#  0.091395   JNJ
#  0.046988   JPM
#  0.029055    KO
# -0.026107   MCD
#  0.329616   MMM
#  0.071390   MRK
#  0.076230  MSFT
#  0.211889   NKE
#  0.023092   PFE
#  0.077732    PG
# -0.007206     T
#  0.189480   TRV
#  0.321564   UNH
#  0.053683   UTX
#  0.579684     V
#  0.000109    VZ
#  0.087161   WMT
# -0.042942   XOM

# %%
# max value for 'V'

# %%
file = open('components.txt', 'wt')
file.write('4')
file.close()

# %%
file = open('corr.txt', 'wt')
file.write(str(cor[0,1]))
file.close()

# %%
file = open('company.txt', 'wt')
file.write('V')
file.close()
